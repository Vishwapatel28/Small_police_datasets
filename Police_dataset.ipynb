# %%
import pandas as pd

# %%
pl =pd.read_csv("police_dataset.csv")

# %%
pl
# Out:
#         stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0      01-02-2005     01:55           NaN             M          1985.0
# 1       1/18/2005     08:15           NaN             M          1965.0
# 2       1/23/2005     23:15           NaN             M          1972.0
# 3       2/20/2005     17:15           NaN             M          1986.0
# 4       3/14/2005     10:00           NaN             F          1984.0
# ...           ...       ...           ...           ...             ...
# 65530  12-06-2012     17:54           NaN             F          1987.0
# 65531  12-06-2012     22:22           NaN             M          1954.0
# 65532  12-06-2012     23:20           NaN             M          1985.0
# 65533  12-07-2012     00:23           NaN           NaN             NaN
# 65534  12-07-2012     00:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %% [markdown]
# # Q1) Remove the column that only contains missing values.

# %%
pl.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
#pl.drop(columns='country_name', inplace=True)
pl
# Out:
#         stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0      01-02-2005     01:55           NaN             M          1985.0
# 1       1/18/2005     08:15           NaN             M          1965.0
# 2       1/23/2005     23:15           NaN             M          1972.0
# 3       2/20/2005     17:15           NaN             M          1986.0
# 4       3/14/2005     10:00           NaN             F          1984.0
# ...           ...       ...           ...           ...             ...
# 65530  12-06-2012     17:54           NaN             F          1987.0
# 65531  12-06-2012     22:22           NaN             M          1954.0
# 65532  12-06-2012     23:20           NaN             M          1985.0
# 65533  12-07-2012     00:23           NaN           NaN             NaN
# 65534  12-07-2012     00:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %% [markdown]
# # Q2) For speeding, were Men or Women stopped more often

# %%
pl[pl.violation == 'Speeding'].driver_gender.value_counts()
# Out:
# driver_gender
# M    25517
# F    11686
# Name: count, dtype: int64

# %%
# Male is more often stopped in speeding.

# %% [markdown]
# # Q3) Does Gender affect who gets searches during a stop?

# %%
pl.groupby('driver_gender').search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %%
pl.search_conducted.value_counts()
# Out:
# search_conducted
# False    63056
# True      2479
# Name: count, dtype: int64

# %% [markdown]
# # Q4) What is the mean stop_duration?

# %%
pl.value_counts('stop_duration')
# Out:
# stop_duration
# 0-15 Min     47379
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: count, dtype: int64

# %%
pl['stop_duration']=pl['stop_duration'].map({'0-15 Min':7.5 , '16-30 Min':24 , '30+ Min':45})
pl
# Out:
#         stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0      01-02-2005     01:55           NaN             M          1985.0
# 1       1/18/2005     08:15           NaN             M          1965.0
# 2       1/23/2005     23:15           NaN             M          1972.0
# 3       2/20/2005     17:15           NaN             M          1986.0
# 4       3/14/2005     10:00           NaN             F          1984.0
# ...           ...       ...           ...           ...             ...
# 65530  12-06-2012     17:54           NaN             F          1987.0
# 65531  12-06-2012     22:22           NaN             M          1954.0
# 65532  12-06-2012     23:20           NaN             M          1985.0
# 65533  12-07-2012     00:23           NaN           NaN             NaN
# 65534  12-07-2012     00:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %%
pl['stop_duration'].mean()
# Out:
# np.float64(12.187420698181345)

# %% [markdown]
# # Q5) Compre the age distributions for each violation?

# %%
pl.groupby('violation').driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             6507.0  31.682957  11.380671  16.0  23.0  28.0  39.0
# Moving violation     11876.0  36.736443  13.258350  15.0  25.0  35.0  47.0
# Other                 3477.0  40.362381  12.754423  16.0  30.0  41.0  50.0
# Registration/plates   2240.0  32.656696  11.150780  16.0  24.0  30.0  40.0
# Seat belt                3.0  30.333333  10.214369  23.0  24.5  26.0  34.0
# Speeding             37120.0  33.262581  12.615781  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  74.0
# Seat belt            42.0
# Speeding             88.0
